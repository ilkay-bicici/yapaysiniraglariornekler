# %% [markdown]
# Prensesi İyileştir (Cure The
# Princess) Veri Seti parçaları kullanılacak.
#
# İki hidden layer’lı bir Multilayer Perceptron (MLP) oluşturun.
# İlk hidden layer’da 100, ikinci hidden layer’da 50 nöron olsun. Hidden layer’larda ReLU, output layer’da sigmoid aktivasyonu olsun.
#
# Output layer’da 1 nöron bulunuyor çünkü binary sınıflandırma yapıyoruz. Buna bağlı olarak binary cross entrophy loss kullanıyoruz.
#
# Optimizasyon için Stochastic Gradient Descent kullandım.
#
# Batch size’ı 16 seçebilirsiniz.
#
# # İlgili kütüphanelerin eklenmesi:

# %%
# !pip install google-colab
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')

#diger importlar
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-colab in /usr/local/lib/python3.9/dist-packages (1.0.0)
# Requirement already satisfied: tornado~=6.2 in /usr/local/lib/python3.9/dist-packages (from google-colab) (6.2)
# Requirement already satisfied: pandas~=1.5.3 in /usr/local/lib/python3.9/dist-packages (from google-colab) (1.5.3)
# Requirement already satisfied: portpicker~=1.3.1 in /usr/local/lib/python3.9/dist-packages (from google-colab) (1.3.9)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.9/dist-packages (from google-colab) (2.27.1)
# Requirement already satisfied: ipykernel~=5.5.6 in /usr/local/lib/python3.9/dist-packages (from google-colab) (5.5.6)
# Requirement already satisfied: notebook==6.4.8 in /usr/local/lib/python3.9/dist-packages (from google-colab) (6.4.8)
# Requirement already satisfied: ipython~=7.34.0 in /usr/local/lib/python3.9/dist-packages (from google-colab) (7.34.0)
# Requirement already satisfied: google-auth>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from google-colab) (2.17.2)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (6.1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (0.16.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (21.3.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (6.5.4)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (23.2.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (5.8.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (1.5.6)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from notebook==6.4.8->google-colab) (0.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.17.2->google-colab) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.17.2->google-colab) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.17.2->google-colab) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth>=1.17.2->google-colab) (4.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (2.14.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (0.1.6)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (67.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython~=7.34.0->google-colab) (4.4.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5.3->google-colab) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5.3->google-colab) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas~=1.5.3->google-colab) (1.22.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.0->google-colab) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.0->google-colab) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.0->google-colab) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.27.0->google-colab) (3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython~=7.34.0->google-colab) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook==6.4.8->google-colab) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython~=7.34.0->google-colab) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython~=7.34.0->google-colab) (0.2.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.17.2->google-colab) (0.4.8)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook==6.4.8->google-colab) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook==6.4.8->google-colab) (2.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (4.11.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (1.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (0.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (23.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (0.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (4.9.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook==6.4.8->google-colab) (0.7.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook==6.4.8->google-colab) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook==6.4.8->google-colab) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook==6.4.8->google-colab) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook==6.4.8->google-colab) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook==6.4.8->google-colab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook==6.4.8->google-colab) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook==6.4.8->google-colab) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook==6.4.8->google-colab) (2.21)
# Installing collected packages: jedi
# Successfully installed jedi-0.18.2
# Mounted at /content/drive

# %% [markdown]
# # Datasetleri çekme ve koda dahil etme:

# %%
# Dosya yolları
train_path = "/content/drive/My Drive/cure_the_princess_train.csv"
valid_path = "/content/drive/My Drive/cure_the_princess_validation.csv"
test_path = "/content/drive/My Drive/cure_the_princess_test.csv"

# Verileri yükle
train_df = pd.read_csv(train_path)
valid_df = pd.read_csv(valid_path)
test_df = pd.read_csv(test_path)

# Verileri görüntüle (test amacli)
print(train_df.head())
print(valid_df.head())
print(test_df.head())

# Girdi (x) ve çıktı (y) sütunlarını ayır
train_x = train_df.iloc[:, :13] #son sutun dahil degil ver setinde 14 sutun var. bu sekilde de olurdu -> torch.Tensor(train_data.iloc[:, :-1].values)
train_y = train_df.iloc[:, 13]  #son sutun dahil bu sekilde de olurdu -> torch.Tensor(train_data.iloc[:, -1].values)

valid_x = valid_df.iloc[:, :13]
valid_y = valid_df.iloc[:, 13]

test_x = test_df.iloc[:, :13]
test_y = test_df.iloc[:, 13]

# Verileri tensorlara dönüştür
train_x = torch.tensor(train_x.values).float()
train_y = torch.tensor(train_y.values).float()

valid_x = torch.tensor(valid_x.values).float()
valid_y = torch.tensor(valid_y.values).float()

test_x = torch.tensor(test_x.values).float()
test_y = torch.tensor(test_y.values).float()
# Out:
#    Phoenix Feather  Unicorn Horn  Dragon's Blood  Mermaid Tears  Fairy Dust  \
# 0             18.8           1.5            19.7            1.1        19.5
# 1              6.0           3.8            12.4           16.9        13.0
# 2             22.4           7.9            28.6           11.2         5.4
# 3             10.8           4.6             5.1           16.7        20.8
# 4              3.7           5.7             9.0            3.3        17.4
#
#    Goblin Toes  Witch's Brew  Griffin Claw  Troll Hair  Kraken Ink  \
# 0         30.1          16.5           9.9        27.3         1.8
# 1         12.6          17.0          25.4         7.7        14.6
# 2          9.3          11.5          10.7         9.4        11.1
# 3         27.1           7.8          15.5        34.0         7.6
# 4         33.3           7.6          20.1        11.5         6.1
#
#    Minotaur Horn  Basilisk Scale  Chimera Fang  Cured
# 0           18.9            25.3           2.0      1
# 1            3.8            23.7          17.9      0
# 2           21.4            29.1           7.5      0
# 3           16.5            27.3           3.2      1
# 4            5.2             6.1           1.9      0
#    Phoenix Feather  Unicorn Horn  Dragon's Blood  Mermaid Tears  Fairy Dust  \
# 0             13.1           7.6            11.6           11.0         4.7
# 1             24.8          26.4            13.4            3.7         8.8
# 2              5.8          21.2             6.8           13.2        26.2
# 3              6.5          13.8            25.5            3.8        12.9
# 4             22.1          17.4             4.9           20.8        10.8
#
#    Goblin Toes  Witch's Brew  Griffin Claw  Troll Hair  Kraken Ink  \
# 0         26.8           6.1           4.5        17.1         8.6
# 1         37.0           1.7          14.3        30.2         5.1
# 2         14.5          20.1          26.4         9.0         3.1
# 3          5.0           1.9          18.7         1.4         9.4
# 4          9.4           7.3          15.2        33.5        15.2
#
#    Minotaur Horn  Basilisk Scale  Chimera Fang  Cured
# 0           10.0            13.7          18.6      0
# 1            2.0             2.7           5.6      1
# 2            6.5            17.9           3.8      1
# 3           24.4            22.7          10.7      0
# 4           20.0            18.6          14.4      1
#    Phoenix Feather  Unicorn Horn  Dragon's Blood  Mermaid Tears  Fairy Dust  \
# 0             10.0          15.3            27.1           13.3        18.1
# 1             31.6           1.9            25.2           17.9        16.4
# 2             22.4           9.2            23.7           14.9        18.2
# 3             24.5           2.3             2.2           26.2         7.3
# 4              3.2          20.2            12.9           13.3         7.7
#
#    Goblin Toes  Witch's Brew  Griffin Claw  Troll Hair  Kraken Ink  \
# 0         12.3           4.8          24.0        10.0        17.5
# 1          2.4           4.2           6.4        32.5        21.9
# 2         10.5           6.8          15.3        21.0        16.8
# 3          2.8          20.6           7.8        23.0        17.0
# 4         29.6           2.6          12.9        12.7        13.8
#
#    Minotaur Horn  Basilisk Scale  Chimera Fang  Cured
# 0            5.9            27.6           8.6      0
# 1           19.7            12.4          17.4      1
# 2           31.6            19.4          11.6      0
# 3            2.7             7.6          26.0      1
# 4            8.9             6.5           9.1      0

# %%
# Veri özelliklerinin ayarlanması
input_size = 8
hidden_size1 = 100
hidden_size2 = 50
output_size = 1

# %% [markdown]
# # Yapay sinir ağımızı oluşturacak sınıf:

# %%
# 5. MLP modelinizi oluşturun.
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.hidden1 = nn.Linear(train_x.shape[1], 100)
        self.relu1 = nn.ReLU()
        self.hidden2 = nn.Linear(100, 50)
        self.relu2 = nn.ReLU()
        self.output = nn.Linear(50, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.hidden1(x)
        x = self.relu1(x)
        x = self.hidden2(x)
        x = self.relu2(x)
        x = self.output(x)
        x = self.sigmoid(x)
        return x

# %% [markdown]
# # Modeli oluşturma ve eğitim döngüsü:

# %%
# Veri yükleyicilerini oluşturma
batch_size = 16
train_loader = DataLoader(TensorDataset(train_x, train_y), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(TensorDataset(valid_x, valid_y), batch_size=batch_size, shuffle=False)

torch.manual_seed(180401002) 

model = MLP()

# Optimizasyon ve kayıp fonksiyonu tanımı
learning_rate = 0.001
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
#optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.BCELoss()

# Eğitim döngüsü
num_epochs = 1000
patience = 10
train_losses = []
val_losses = []
best_val_loss = None
for epoch in range(num_epochs):
    # Eğitim aşaması
    model.train()
    train_loss = 0.0
    train_count = 0.0
    for x_batch, y_batch in train_loader:
        optimizer.zero_grad()
        y_pred = model(x_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        train_count += 1.0
        train_loss += loss.item()
    #train_loss /= train_count #len(train_loader)
    #train_losses.append(train_loss)

    # Doğrulama aşaması
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for x_batch, y_batch in val_loader:
            y_pred = model(x_batch).squeeze()
            loss = criterion(y_pred, y_batch)
            val_loss += loss.item()
    #val_loss /= len(val_loader)
    #val_losses.append(val_loss)

    # calculate metrics
    train_loss /= train_count
    val_loss /= len(val_loader)

    print("Epoch", epoch, "Training loss", train_loss,"Validation Loss :",val_loss)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    #en iyi modeli tutmak icin
    val_score = val_loss
    if best_val_loss is None:
        best_val_loss = val_score # hafızada patience boyu tutmaya başla
        torch.save(model.state_dict(), "checkpoint.pt")
    elif best_val_loss < val_score: # patience counter
        patience_counter += 1
        print("Earlystopping Patience Counter:",patience_counter)
        if patience_counter == patience:
            break
    else:
        best_val_loss = val_score
        torch.save(model.state_dict(), "checkpoint.pt") # to keep the best model
        patience_counter = 0

# Eğitim ve doğrulama kayıplarını görselleştirme
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 0 Training loss 0.7045979597900487 Validation Loss : 0.6225213229656219
# Epoch 1 Training loss 0.6028067865703679 Validation Loss : 0.5580104053020477
# Epoch 2 Training loss 0.5544985238509842 Validation Loss : 0.5182509526610375
# Epoch 3 Training loss 0.5176991801473159 Validation Loss : 0.477714492380619
# Epoch 4 Training loss 0.4902843127522287 Validation Loss : 0.4452960088849068
# Epoch 5 Training loss 0.4661233093165144 Validation Loss : 0.4276551306247711
# Epoch 6 Training loss 0.43801259504088874 Validation Loss : 0.3980312436819077
# Epoch 7 Training loss 0.4158639345742479 Validation Loss : 0.3766884535551071
# Epoch 8 Training loss 0.39638431087324894 Validation Loss : 0.3615158416330814
# Epoch 9 Training loss 0.3786108044883873 Validation Loss : 0.3465790368616581
# Epoch 10 Training loss 0.361471351566194 Validation Loss : 0.3281131833791733
# Epoch 11 Training loss 0.3520395438882369 Validation Loss : 0.31688149720430375
# Epoch 12 Training loss 0.337866437586048 Validation Loss : 0.30382046923041345
# Epoch 13 Training loss 0.326349213719368 Validation Loss : 0.2995486356317997
# Earlystopping Patience Counter: 2
# Epoch 112 Training loss 0.14041261455114884 Validation Loss : 0.26839989311993123
# Earlystopping Patience Counter: 3
# Epoch 113 Training loss 0.14705343704812135 Validation Loss : 0.21299951151013374
# Earlystopping Patience Counter: 4
# Epoch 114 Training loss 0.13552607052452578 Validation Loss : 0.17128069344907998
# Epoch 115 Training loss 0.13803318279642093 Validation Loss : 0.17874345537275077
# Earlystopping Patience Counter: 1
# Epoch 116 Training loss 0.13461614470881753 Validation Loss : 0.17411708999425174
# Earlystopping Patience Counter: 2
# Epoch 117 Training loss 0.13112877685388055 Validation Loss : 0.17277365662157534
# Earlystopping Patience Counter: 3
# Epoch 118 Training loss 0.13105871221875842 Validation Loss : 0.16920177303254605
# Epoch 119 Training loss 0.1315155486705937 Validation Loss : 0.17147668525576593
# Earlystopping Patience Counter: 1
# Epoch 120 Training loss 0.1300197308529404 Validation Loss : 0.19006178360432385
# Earlystopping Patience Counter: 2
# Epoch 121 Training loss 0.13046347720053378 Validation Loss : 0.17749257609248162
# Earlystopping Patience Counter: 3
# Epoch 122 Training loss 0.1273772493653188 Validation Loss : 0.16892581693828107
# Epoch 123 Training loss 0.12793655285635328 Validation Loss : 0.16705425251275302
# Epoch 124 Training loss 0.12879543518058106 Validation Loss : 0.16996567342430352
# Earlystopping Patience Counter: 1
# Epoch 125 Training loss 0.12752414614999596 Validation Loss : 0.16572818867862224
# Epoch 126 Training loss 0.12458802508543941 Validation Loss : 0.17614348586648704
# Earlystopping Patience Counter: 1
# Epoch 127 Training loss 0.1268982450371679 Validation Loss : 0.1716443281620741
# Earlystopping Patience Counter: 2
# Epoch 128 Training loss 0.12299482109425944 Validation Loss : 0.16734499726444482
# Earlystopping Patience Counter: 3
# Epoch 129 Training loss 0.12427355633765648 Validation Loss : 0.17538026608526708
# Earlystopping Patience Counter: 4
# Epoch 130 Training loss 0.1272058842019944 Validation Loss : 0.17047000601887702
# Earlystopping Patience Counter: 5
# Epoch 131 Training loss 0.12378330024171479 Validation Loss : 0.16852740235626698
# Earlystopping Patience Counter: 6
# Epoch 132 Training loss 0.12149061988803404 Validation Loss : 0.17030032463371753
# Earlystopping Patience Counter: 7
# Epoch 133 Training loss 0.12443889356866668 Validation Loss : 0.17270024102181197
# Earlystopping Patience Counter: 8
# Epoch 134 Training loss 0.12110835125174703 Validation Loss : 0.16595371924340724
# Earlystopping Patience Counter: 9
# Epoch 135 Training loss 0.11968465332130465 Validation Loss : 0.17018339838832616
# Earlystopping Patience Counter: 10

# %% [markdown]
# # Modeli test etme:

# %%
# Test aşaması
model.eval()
with torch.no_grad():
    y_pred = model(test_x).squeeze().numpy()
    y_pred_rounded = [round(pred) for pred in y_pred]
    acc = accuracy_score(test_y, y_pred_rounded)
    f1 = f1_score(test_y, y_pred_rounded)
    precision = precision_score(test_y, y_pred_rounded)
    recall = recall_score(test_y, y_pred_rounded)

# Test sonuçlarını yazdırma
print(f'Accuracy: {acc:.4f}')
print(f'F1 Score: {f1:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
# Out:
# Accuracy: 0.9391
# F1 Score: 0.9372
# Precision: 0.9723
# Recall: 0.9046
